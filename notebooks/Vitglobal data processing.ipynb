# %%
# %load_ext autoreload 
# %autoreload 2

import yaml
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from pathlib import Path, PurePath
from IPython.display import Audio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dataset = Path('../../datasets/VitGlobal/meta/')
excel = 'VITGLOBAL_AUDIO_CLASIFICADO_20221231_VEHICULAR.xlsx'
csv = 'audios_eruido2022_20220121.csv'

# %%
new_data = pd.read_excel(dataset / excel)
old_data = pd.read_csv(dataset / csv)

# %%
new_data = new_data[['WAVE_FILE', 'WAVE_URL', 'WAVE_MEMO', 'ERUIDO_UNIT']]

# %%
new_data.to_csv(dataset / 'audios_eruido1995.csv')

# %%
audios = Path('../../datasets/VitGlobal/audio/dataset_20221231/')

# %%
import requests
for url in new_data['WAVE_URL']:
    response = requests.get(url)
    open(audios / url.split('/')[-1], "wb").write(response.content)

# %%
new_data['WAVE_URL']
# Out:
# 0       https://audio2.ruido.net/audios/eruido1995/mp3...
# 1       https://audio2.ruido.net/audios/eruido1995/mp3...
# 2       https://audio2.ruido.net/audios/eruido1995/mp3...
# 3       https://audio2.ruido.net/audios/eruido1995/mp3...
# 4       https://audio2.ruido.net/audios/eruido1995/mp3...
#                               ...
# 1113    https://audio2.ruido.net/audios/eruido1995/mp3...
# 1114    https://audio2.ruido.net/audios/eruido1995/mp3...
# 1115    https://audio2.ruido.net/audios/eruido1995/mp3...
# 1116    https://audio2.ruido.net/audios/eruido1995/mp3...
# 1117    https://audio2.ruido.net/audios/eruido1995/mp3...
# Name: WAVE_URL, Length: 1118, dtype: object

# %%
old_data
# Out:
#                    TIMEID_BIN  WAVE_CATEGORY       WAVE_FILE  \
# 0     2021-10-01 00:26:57.700              4  20211001002657
# 1     2021-10-01 00:08:29.743              1  20211001000829
# 2     2021-10-01 00:08:21.707              1  20211001000821
# 3     2021-10-01 00:01:37.457              1  20211001000137
# 4     2021-10-01 01:45:50.837              4  20211001014550
# ...                       ...            ...             ...
# 1186  2021-12-20 21:17:29.200              4  20211220211729
# 1187  2021-12-20 21:17:37.247              4  20211220211737
# 1188  2021-12-20 21:15:13.837              4  20211220211513
# 1189  2021-12-20 21:15:22.860              4  20211220211522
# 1190  2021-12-20 21:16:04.000              4  20211220211604
#
#                                                WAVE_URL         WAVE_MEMO  \
# 0     https://audio2.ruido.net/audios/eruido2022/mp3...            APILAR
# 1     https://audio2.ruido.net/audios/eruido2022/mp3...              MOTO
# ...
